# %%
paths_dict = {
    "input_dir" : "/growths/"
}

# %% [markdown]
# ## Read Data from Dataset

# %%
# Read data
gdp = pd.read_csv(os.path.join(paths_dict['input_dir'], 'gdp.csv'), index_col=0)
gdp_growth = pd.read_csv(os.path.join(paths_dict['input_dir'], 'gdp_growth.csv'), index_col=0)
gdp_per_capita = pd.read_csv(os.path.join(paths_dict['input_dir'], 'gdp_per_capita.csv'), index_col=0)
gdp_per_capita_growth = pd.read_csv(os.path.join(paths_dict['input_dir'], 'gdp_per_capita_growth.csv'), index_col=0)
gdp_ppp = pd.read_csv(os.path.join(paths_dict['input_dir'], 'gdp_ppp.csv'), index_col=0)
gdp_ppp_per_capita = pd.read_csv(os.path.join(paths_dict['input_dir'], 'gdp_ppp_per_capita.csv'), index_col=0)

# %% [markdown]
# ### GDP($)

# %%
gdp.head()
# Out:
#                             Code          1960          1961          1962  \
# Country Name
# Aruba                        ABW           NaN           NaN           NaN
# Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10  2.149392e+10
# Afghanistan                  AFG  5.377778e+08  5.488889e+08  5.466667e+08
# Africa Western and Central   AFW  1.040428e+10  1.112805e+10  1.194335e+10
# Angola                       AGO           NaN           NaN           NaN
#
#                                      1963          1964          1965  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  2.573321e+10  2.352744e+10  2.681057e+10
# Afghanistan                  7.511112e+08  8.000000e+08  1.006667e+09
# Africa Western and Central   1.267652e+10  1.383858e+10  1.486247e+10
# Angola                                NaN           NaN           NaN
#
# ...

# %% [markdown]
# ### GDP Growth

# %%
gdp_growth.head()
# Out:
#                             Code  1960      1961      1962      1963  \
# Country Name
# Aruba                        ABW   NaN       NaN       NaN       NaN
# Africa Eastern and Southern  AFE   NaN       NaN       NaN       NaN
# Afghanistan                  AFG   NaN       NaN       NaN       NaN
# Africa Western and Central   AFW   NaN  1.848719  3.770212  7.272501
# Angola                       AGO   NaN       NaN       NaN       NaN
#
#                                  1964      1965      1966      1967      1968  \
# Country Name
# Aruba                             NaN       NaN       NaN       NaN       NaN
# Africa Eastern and Southern       NaN       NaN       NaN       NaN       NaN
# Afghanistan                       NaN       NaN       NaN       NaN       NaN
# Africa Western and Central   5.396356  4.049794 -1.787094 -9.546521  1.465741
# Angola                            NaN       NaN       NaN       NaN       NaN
#
# ...

# %% [markdown]
# ### GDP per capitia($)

# %%
gdp_per_capita.head()
# Out:
#                             Code        1960        1961        1962  \
# Country Name
# Aruba                        ABW         NaN         NaN         NaN
# Africa Eastern and Southern  AFE  147.612227  147.014904  156.189192
# Afghanistan                  AFG   59.773234   59.860900   58.458009
# Africa Western and Central   AFW  107.932233  113.081647  118.831107
# Angola                       AGO         NaN         NaN         NaN
#
#                                    1963        1964        1965        1966  \
# Country Name
# Aruba                               NaN         NaN         NaN         NaN
# Africa Eastern and Southern  182.243917  162.347592  180.214908  190.845484
# Afghanistan                   78.706429   82.095307  101.108325  137.594298
# Africa Western and Central   123.442888  131.854402  138.526332  144.326212
# Angola                              NaN         NaN         NaN         NaN
#
# ...

# %% [markdown]
# ### GDP per capita Growth

# %%
gdp_per_capita_growth.head()
# Out:
#                             Code  1960      1961      1962      1963     1964  \
# Country Name
# Aruba                        ABW   NaN       NaN       NaN       NaN      NaN
# Africa Eastern and Southern  AFE   NaN       NaN       NaN       NaN      NaN
# Afghanistan                  AFG   NaN       NaN       NaN       NaN      NaN
# Africa Western and Central   AFW   NaN -0.232405  1.602299  4.990675  3.12468
# Angola                       AGO   NaN       NaN       NaN       NaN      NaN
#
#                                  1965      1966       1967      1968  ...  \
# Country Name                                                          ...
# Aruba                             NaN       NaN        NaN       NaN  ...
# Africa Eastern and Southern       NaN       NaN        NaN       NaN  ...
# Afghanistan                       NaN       NaN        NaN       NaN  ...
# Africa Western and Central   1.783947 -3.946431 -11.557321 -0.819528  ...
# ...

# %% [markdown]
# ### GDP PPP($)

# %%
gdp_ppp.head()
# Out:
#                             Code  1960  1961  1962  1963  1964  1965  1966  \
# Country Name
# Aruba                        ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern  AFE   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan                  AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Western and Central   AFW   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola                       AGO   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                              1967  1968  ...          2012          2013  \
# Country Name                             ...
# Aruba                         NaN   NaN  ...  3.442856e+09  3.799467e+09
# Africa Eastern and Southern   NaN   NaN  ...  1.772679e+12  1.893539e+12
# Afghanistan                   NaN   NaN  ...  5.966700e+10  6.503984e+10
# Africa Western and Central    NaN   NaN  ...  1.396677e+12  1.526772e+12
# Angola                        NaN   NaN  ...  1.861242e+11  1.998656e+11
#
# ...

# %% [markdown]
# ### GDP PPP($) per capita

# %%
gdp_ppp_per_capita.head()
# Out:
#                             Code  1960  1961  1962  1963  1964  1965  1966  \
# Country Name
# Aruba                        ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern  AFE   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan                  AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Western and Central   AFW   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola                       AGO   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                              1967  1968  ...          2012          2013  \
# Country Name                             ...
# Aruba                         NaN   NaN  ...  33567.550017  36829.032774
# Africa Eastern and Southern   NaN   NaN  ...   3237.870658   3365.682977
# Afghanistan                   NaN   NaN  ...   1914.774228   2015.514775
# Africa Western and Central    NaN   NaN  ...   3772.323802   4013.196523
# Angola                        NaN   NaN  ...   7412.967035   7682.475386
#
# ...

# %% [markdown]
# ## GDP Types Visualization

# %%
def visualize_GDP(input_gdp, title, country_codes=[ 'TUR', 'POL', 'GRC'], year_intervals=['1995', '2019'], unit='Dollars'):
    
    title = f'{title} during {year_intervals[0]} - {year_intervals[1]}'
    
    first_year = int(year_intervals[0])
    last_year = int(year_intervals[1])
    
    
    plt.figure(figsize=(24,6))
    plt.title(label=title,fontsize=20,fontweight=20)
    plt.ylabel(unit,fontsize=25)
    plt.xlabel('Years',fontsize=25)
    for code in country_codes:
        plt.plot(np.arange(first_year,last_year),input_gdp.loc[input_gdp['Code'] == code].iloc[0,37:-2],linewidth=3,label=code)

    plt.xticks(np.arange(first_year,last_year),np.arange(first_year,last_year),rotation=0)
    plt.grid()
    plt.legend()
    plt.show()
    print('\n')

# %%
visualize_GDP(gdp, 'GDP')
visualize_GDP(gdp_per_capita, 'GDP per capita')
visualize_GDP(gdp_ppp, 'GDP PPP')
visualize_GDP(gdp_ppp_per_capita, 'GDP PPP per capita')

visualize_GDP(gdp_growth, 'GDP Growth(Annually)', unit='Ratio')
visualize_GDP(gdp_per_capita_growth, 'GDP per capita Growth(Annually)', unit='Ratio')

# %% [markdown]
# ## Calculate GDP growth between years in %

# %%
def calculate_gdp_growth_between_years(input_df, start_year, end_year, country_code):
    first_gdp = float(input_df[input_df['Code']==country_code][start_year])
    last_gdp = float(input_df[input_df['Code']==country_code][end_year])
    growth = ((last_gdp - first_gdp) / (last_gdp + first_gdp)) * 100
    return round(growth, 4)

# %%
calculate_gdp_growth_between_years(gdp, '2001', '2013', 'KOR')
# Out:
# 42.9063

# %%
calculate_gdp_growth_between_years(gdp, '2001', '2013', 'DEU')
# Out:
# 31.5075
